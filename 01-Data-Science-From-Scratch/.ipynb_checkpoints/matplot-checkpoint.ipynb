# %%
from matplotlib import pyplot as plt

"""Graph is a nice method to visualize timeseries data."""

#data
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

#draw
plt.plot(years, gdp, color='green', marker="o",linestyle='solid')

#title
plt.title("Nominal GDP")

#label
plt.ylabel("Billions of $")

plt.show()

# %%
movies = ["Annnie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]
graphx = [i + 0.1 for i, _ in enumerate(movies)]
plt.bar(graphx, num_oscars, color='pink')
plt.title("Some movies")
plt.ylabel("# of Academy Awards")
plt.xticks([i + 0.5 for i, _ in enumerate(movies)],movies)
plt.show()

# %%
graphx
# Out:
# [0.1, 1.1, 2.1, 3.1, 4.1]

# %%
from collections import Counter

#data
grades = [83,95,91,87,70,85,84,80,82,0,100,67,63,74,77,0,25,47,42]

#decile
decile = lambda grade: grade // 10 * 10

#Count each decile 
histogram = Counter(decile(grade) for grade in grades)

"""
Draw a bar chart.
for decile, place bar to the left '4'
label it with values.
thickness of bar is 8 and color is black.
"""

plt.bar([x - 4 for x in histogram.keys()],
       histogram.values(),
       8,
       color='black')

plt.axis([-5, 105, 0, 7])  # xy축 길이
plt.xticks([10 * i for i in range(11)])
plt.ylabel("Number of Students")
plt.xlabel("Decile of grade")
plt.show()

# %%
histogram
# Out:
# Counter({0: 2, 20: 1, 40: 2, 60: 2, 70: 3, 80: 6, 90: 2, 100: 1})

# %%
variance = [1,2,4,8,16,32,64,128,256]
bias_squared = [256,128,64,32,16,8,4,2,1]
total_error = [x+y for x,y in zip(variance, bias_squared)]

xs = [i for i, _ in enumerate(variance)]
plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias_squared, 'r-', label='bias^2')
plt.plot(xs, total_error, 'b:', label='total error')

#각 series에 label을 만들어 줬기 때문에 범례를 나타낼 수 있다.
plt.legend(loc=5)
plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %%
users = [70,65,72,63,71,64,60,64,67]
minutes = [175,170,205,120,220,130,105,145,190]
labels = ['a','b','c','d','e','f','g','h','i']

plt.scatter(users, minutes)
for label, user_count, minute_count in zip(labels, users, minutes):
    plt.annotate(label,
                 xy=(user_count, minute_count),
                 xytext=(5, -5),
                 textcoords="offset points")
    
plt.title("Daily Minutes vs Number of users")
plt.xlabel("Number of users")
plt.ylabel("Daily minutes spent on site")
plt.show()

# %%
list(zip(labels, users, minutes))
# Out:
# [('a', 70, 175),
#  ('b', 65, 170),
#  ('c', 72, 205),
#  ('d', 63, 120),
#  ('e', 71, 220),
#  ('f', 64, 130),
#  ('g', 60, 105),
#  ('h', 64, 145),
#  ('i', 67, 190)]

# %%
import pandas as pd
data = pd.read_csv('./schoolmeal.csv')

# %%
data.head()
# Out:
#   ﻿menuName    servedAt  score  pollCount  assessment  lunchCount  \
# 0      배추김치  2016-12-29      0          0         NaN         254
# 1       보리밥  2016-12-13      0          0         NaN          69
# 2       깍두기  2016-12-28      0          0         NaN          53
# 3     혼합잡곡밥  2016-12-15      0          0         NaN          51
# 4      열무김치  2016-12-14      0          0         NaN          33
#
#    dinnerCount       lastUpdated  Unnamed: 8
# 0          182  2017-01-02 21:58         NaN
# 1           54  2017-01-02 21:58         NaN
# 2           56  2017-01-02 21:58         NaN
# 3           36  2017-01-02 21:58         NaN
# 4           14  2017-01-02 21:58         NaN

# %%
data.shape
# Out:
# (25, 9)

# %%
list(data.iteritems())[0][1]
# Out:
# 0        배추김치
# 1         보리밥
# 2         깍두기
# 3       혼합잡곡밥
# 4        열무김치
# 5          사과
# 6         흑미밥
# 7       발아현미밥
# 8          수박
# 9         현미밥
# 10         우유
# 11       총각김치
# 12        기장밥
# 13         메론
# 14          귤
# 15         팥밥
# 16      아욱된장국
# 17        율무밥
# 18     생배추된장국
# 19       요구르트
# 20       차수수밥
# 21        약콩밥
# 22      근대된장국
# 23      고추잎무침
# 24    돼지야채불고기
# Name: ﻿menuName, dtype: object

# %%
str_list = []
for colname, colvalue in data.iteritems():
    if type(colvalue[1]) == str:
        str_list.append(colname)
        
str_list
# Out:
# ['\ufeffmenuName', 'servedAt', 'lastUpdated']
